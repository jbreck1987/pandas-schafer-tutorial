# %%
import pandas as pd

# %%
df = pd.read_csv('data/grad_school_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   School                       87 non-null     object
#  1   Department                   87 non-null     object
#  2   Admission Deadline           87 non-null     object
#  3   Application Fee              87 non-null     object
#  4   Students Applied fall 2019   85 non-null     float64
#  5   Students Admitted Fall 2019  86 non-null     float64
#  6   Students Enrolled Fall 2019  85 non-null     float64
#  7   Percent Acceptance           85 non-null     object
#  8   Minimum Undergrad GPA        63 non-null     float64
#  9   General GRE Required?        87 non-null     object
#  10  Physics GRE Required?        87 non-null     object
#  11  Teaching Assistant Stipend   86 non-null     object
#  12  Research Assistant Stipend   80 non-null     object
# ...

# %%
df.head()
# Out:
#                              School                       Department  \
# 0                            Auburn                          Physics
# 1             University of Alabama            Physics and Astronomy
# 2  University of Alabama Birmingham                          Physics
# 3       Northern Arizona University  Astronomy and Planetary Science
# 4             University of Arizona                          Physics
#
#   Admission Deadline Application Fee  Students Applied fall 2019  \
# 0         March 15th            $60                         30.0
# 1       January 15th            $65                         88.0
# 2           July 1st            $50                         50.0
# 3        January 1st            $65                         70.0
# 4        January 1st            $85                        179.0
#
#    Students Admitted Fall 2019  Students Enrolled Fall 2019  \
# 0                         12.0                         12.0
# ...

# %%
df_accept_stip = df.loc[0:, ['School', 'Percent Acceptance', 'Teaching Assistant Stipend']].sort_values(by='Percent Acceptance', ascending=False)

# %%
df_accept_stip.sort_values(by=['Teaching Assistant Stipend'])
# Out:
#                                       School Percent Acceptance  \
# 41    University of Massachusetts, Dartmouth             76.19%
# 43         Michigan Technological University             52.76%
# 35                       University of Maine             47.06%
# 64                         Miami University              20.83%
# 5                San Diego State University              58.30%
# ..                                       ...                ...
# 55                       Columbia University              9.94%
# 40     Massachusetts Institute of Technology             10.60%
# 15  University of Colorado, Colorado Springs             79.20%
# 59              Appalachian State University               100%
# 6                                   Stanford              9.60%
#
#          Teaching Assistant Stipend
# 41                         $16,000
# 43                         $16,238
# 35                         $17,340
# 64                         $17,406
# ...
